# %% [markdown]
# <a href="https://colab.research.google.com/github/clarkti5/introduction-to-statistics/blob/main/1_1_Case_study_Using_stents_to_prevent_strokes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case study: using stents to prevent strokes

# %% [markdown]
# ---
#
# #### Summary videos
#
# - [Case study: using stents to prevent strokes](https://youtu.be/nEHFF1ADpWE?si=xWZaj1Y4Ckj6BGhu) (4 minutes)
#
# #### Walkthrough videos
#
# - [Using stents to prevent strokes](https://drive.google.com/file/d/1ANbJiWIiudT1o2lZK9Ok3tTtThylQi-H/view?usp=sharing) (12 minutes)
#
# ---

# %% [markdown]
# Stents are devices put inside blood vessels that assist in patient recovery after cardiac events and reduce the risk of an additional heart attack or death. Many doctors hoped that there would be similar benefits for patients at risk of stroke.

# %% [markdown]
# ### Question
#
# > Does the use of stents reduce the risk of stroke?

# %% [markdown]
# The researchers who asked this question conducted an **experiment** with 451 at-risk patients. Each volunteer patient was randomly assigned to one of two groups:
#
# - **Treatment group.** Patients in the treatment group received a stent and medical management. The medical management included medications, management of risk factors, and help in lifestyle modification.
#
# - **Control group.** Patients in the control group received the same medical management as the treatment group, but they did not receive stents.
#
# Let's take a look at the resulting data.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

stent = pd.read_csv('https://raw.githubusercontent.com/clarkti5/math-209-data-sets/refs/heads/main/stent.csv')

# %%
stent.head()

# %%
stent.tail()

# %%
stent.describe()

# %% [markdown]
# Now we can compare how the outcomes between the treatment and control groups.

# %%
pd.crosstab(stent['Group'], stent['Outcome 0-30 days'], margins = True, margins_name = 'Total')

# %%
pd.crosstab(stent['Group'], stent['Outcome 0-365 days'], margins = True, margins_name = 'Total')

# %% [markdown]
# ### Exercise
#
# - How many patients were in the treatment group? What about the control group?
# - How would you compare the 0-30 days outcomes to the 0-365 days outcomes?
# - How many patients in the control group had a stroke after 1 year?
# - How many patients in the treatment group had a stroke after 1 year?

# %% [markdown]
# While sometimes comparing the raw totals is an effective method of comparison across groups, **proportions** are usually better suited when the groups have different population sizes.

# %% [markdown]
# ### Exercise
#
# - What proportion of patients in the control group had a stroke after 1 year?
# - What proportion of patients in the treatment group had a stroke after 1 year?
# - Does this data seem to suggest that stents are effective in preventing strokes?

# %% [markdown]
# ### Questions
#
# - Is this outcome what you **expected**?
# - Can you describe the importance of the **statistical analysis** done in this context?
# - Are these findings **statistically significant**, or is it reasonably **likely** that the observed difference in proportions is due to **random chance**?

# %% [markdown]
# The second questions is subtle and difficult to answer at the moment, but we'll be developing tools throughout the semester to answer it!

# %% [markdown]
# ---
#
# This notebook was written by Timothy L. Clark, derivative of [OpenIntro Statistics by Diez, Çetinkaya-Rundel, and Barr](https://www.openintro.org/book/os/), released under [Creative Commons BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0/deed.en) license.
