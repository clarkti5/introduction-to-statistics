# %% [markdown]
# # Sampling from a small population

# %% [markdown]
# ---
#
# #### Walkthrough videos
#
# - [Sampling from a small population](https://drive.google.com/file/d/1buHtQepK_TEUiiYd-LLQ4d0v2cELBIpZ/view?usp=sharing) (14 minutes)
#
# ---

# %% [markdown]
# Consider the following exercise from page 114 of the textbook.
#
# Here "drawing with replacement" means that, after drawing a ball, it is placed back in the urn (so it has a chance of being drawn again).
#
# ![Screenshot 2024-09-12 at 11.02.15 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Followup questions
# * When drawing *without* replacement, is each draw independent of the next?
# * How do the solutions to parts (b)–(e) change if we draw without replacment instead?

# %% [markdown]
# Here is another problem from page 114 of the textbook.
#
# ![Screenshot 2024-09-16 at 11.02.30 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Example
#
# What is the probability of drawing a fiction book first and then a hardcover book second, when drawing without replacement?

# %% [markdown]
# ---
#
# This notebook was written by Timothy L. Clark, derivative of [OpenIntro Statistics by Diez, Çetinkaya-Rundel, and Barr](https://www.openintro.org/book/os/), released under [Creative Commons BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0/deed.en) license.
